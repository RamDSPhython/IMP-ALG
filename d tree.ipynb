# %%
import pandas as pd

# %%
df=pd.read_csv("TREE.csv")

# %%
df.head()
# Out:
#   company                job education  sal_more_than_50K
# 0     TCS  PROJECT EXECUTIVE    B.TECH                  0
# 1     TCS  PROJECT EXECUTIVE    M.TECH                  0
# 2     TCS    PROJECT MANAGER    B.TECH                  1
# 3     TCS    PROJECT MANAGER    M.TECH                  1
# 4     TCS         PROGRAMMER    B.TECH                  0

# %%
x=df.drop("sal_more_than_50K",axis="columns")

# %%
x
# Out:
#       company                job education
# 0         TCS  PROJECT EXECUTIVE    B.TECH
# 1         TCS  PROJECT EXECUTIVE    M.TECH
# 2         TCS    PROJECT MANAGER    B.TECH
# 3         TCS    PROJECT MANAGER    M.TECH
# 4         TCS         PROGRAMMER    B.TECH
# 5         TCS         PROGRAMMER    M.TECH
# 6     INFOSYS  PROJECT EXECUTIVE    M.TECH
# 7     INFOSYS         PROGRAMMER    B.TECH
# 8     INFOSYS    PROJECT MANAGER    B.TECH
# 9     INFOSYS    PROJECT MANAGER    M.TECH
# 10  MICROSOFT  PROJECT EXECUTIVE    B.TECH
# 11  MICROSOFT  PROJECT EXECUTIVE    M.TECH
# 12  MICROSOFT    PROJECT MANAGER    B.TECH
# 13  MICROSOFT    PROJECT MANAGER    M.TECH
# 14  MICROSOFT         PROGRAMMER    B.TECH
# 15  MICROSOFT         PROGRAMMER    M.TECH

# %%
y=df["sal_more_than_50K"]

# %%
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     0
# 5     1
# 6     0
# 7     0
# 8     0
# 9     1
# 10    1
# 11    1
# 12    1
# 13    1
# 14    1
# 15    1
# Name: sal_more_than_50K, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le_company=LabelEncoder()
le_job=LabelEncoder()
le_education = LabelEncoder()

# %%
df['company_n']=le_company.fit_transform(df['company'])
df['job_n']=le_company.fit_transform(df['job'])
df['education_n']=le_company.fit_transform(df['education'])

# %%
df
# Out:
#       company                job education  sal_more_than_50K  company_n  \
# 0         TCS  PROJECT EXECUTIVE    B.TECH                  0          2
# 1         TCS  PROJECT EXECUTIVE    M.TECH                  0          2
# 2         TCS    PROJECT MANAGER    B.TECH                  1          2
# 3         TCS    PROJECT MANAGER    M.TECH                  1          2
# 4         TCS         PROGRAMMER    B.TECH                  0          2
# 5         TCS         PROGRAMMER    M.TECH                  1          2
# 6     INFOSYS  PROJECT EXECUTIVE    M.TECH                  0          0
# 7     INFOSYS         PROGRAMMER    B.TECH                  0          0
# 8     INFOSYS    PROJECT MANAGER    B.TECH                  0          0
# 9     INFOSYS    PROJECT MANAGER    M.TECH                  1          0
# 10  MICROSOFT  PROJECT EXECUTIVE    B.TECH                  1          1
# 11  MICROSOFT  PROJECT EXECUTIVE    M.TECH                  1          1
# ...

# %%
df_n=df.drop(['company','job','education'],axis='columns')

# %%
df_n
# Out:
#     sal_more_than_50K  company_n  job_n  education_n
# 0                   0          2      1            0
# 1                   0          2      1            1
# 2                   1          2      2            0
# 3                   1          2      2            1
# 4                   0          2      0            0
# 5                   1          2      0            1
# 6                   0          0      1            1
# 7                   0          0      0            0
# 8                   0          0      2            0
# 9                   1          0      2            1
# 10                  1          1      1            0
# 11                  1          1      1            1
# 12                  1          1      2            0
# 13                  1          1      2            1
# 14                  1          1      0            0
# 15                  1          1      0            1

# %%
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     0
# 5     1
# 6     0
# 7     0
# 8     0
# 9     1
# 10    1
# 11    1
# 12    1
# 13    1
# 14    1
# 15    1
# Name: sal_more_than_50K, dtype: int64

# %%
from sklearn import tree
model=tree.DecisionTreeClassifier()

# %%
model.fit(df_n,y)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
y=df_n.drop(['company_n','job_n','education_n'],axis='columns')

# %%
y
# Out:
#     sal_more_than_50K
# 0                   0
# 1                   0
# 2                   1
# 3                   1
# 4                   0
# 5                   1
# 6                   0
# 7                   0
# 8                   0
# 9                   1
# 10                  1
# 11                  1
# 12                  1
# 13                  1
# 14                  1
# 15                  1

# %%
x=df_n.drop(['sal_more_than_50K'],axis='columns')

# %%
x
# Out:
#     company_n  job_n  education_n
# 0           2      1            0
# 1           2      1            1
# 2           2      2            0
# 3           2      2            1
# 4           2      0            0
# 5           2      0            1
# 6           0      1            1
# 7           0      0            0
# 8           0      2            0
# 9           0      2            1
# 10          1      1            0
# 11          1      1            1
# 12          1      2            0
# 13          1      2            1
# 14          1      0            0
# 15          1      0            1

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
from sklearn import tree
model=tree.DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(x,y)
# Out:
# 0.8125

# %%
pred=model.predict(x_test)

# %%
import numpy as np
val=model.predict([[2,1,0]])
val
# Out:
# array([1], dtype=int64)

# %%
df_n
# Out:
#     sal_more_than_50K  company_n  job_n  education_n
# 0                   0          2      1            0
# 1                   0          2      1            1
# 2                   1          2      2            0
# 3                   1          2      2            1
# 4                   0          2      0            0
# 5                   1          2      0            1
# 6                   0          0      1            1
# 7                   0          0      0            0
# 8                   0          0      2            0
# 9                   1          0      2            1
# 10                  1          1      1            0
# 11                  1          1      1            1
# 12                  1          1      2            0
# 13                  1          1      2            1
# 14                  1          1      0            0
# 15                  1          1      0            1
